# %% [markdown]
# ### Trabalho Prático - ANADI
# #### Grupo:
# *Mariana Martins*
# Luna Gomes
# Samara Miranda
#
# #### 1. Importação de Bibliotecas e Dados
# #### 2. Análise Exploratória (Estatística Descritiva)
# #### 3. Tratamento de Dados (Valores NA e Outliers)
