# %% [markdown]
# ### 1º Trabalho Prático - ANADI
# #### Grupo 8:
# ##### Mariana Martins 1230679
# ##### Luna Gomes
# ##### Samara Miranda

# %% [markdown]
# ### 1. Importação de Bibliotecas e Dados

# %%
# !pip install pandas numpy matplotlib seaborn scipy statsmodels plotly streamlit openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (0.13.2)
# Requirement already satisfied: scipy in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (1.15.3)
# Requirement already satisfied: statsmodels in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (0.14.6)
# Requirement already satisfied: plotly in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (6.6.0)
# Requirement already satisfied: streamlit in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (1.55.0)
# Requirement already satisfied: openpyxl in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (3.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from plotly) (2.17.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from streamlit) (7.0.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from streamlit) (4.25.8)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from streamlit) (23.0.1)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from streamlit) (6.5.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: colorama in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.10.5)
# Requirement already satisfied: et-xmlfile in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in c:\users\maria\anaconda3\envs\tf217\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ### 2. Visualização Inicial dos Datasets

# %%
import pandas as pd
import numpy as np

# 1. Carregar os dados
# O parâmetro na_values converte automaticamente "N/D" em valores nulos (NaN)
df_ip = pd.read_excel('IP_data.xlsx', na_values='N/D')
df_pt = pd.read_excel('PTD_data.xlsx', na_values='N/D')

# 2. Ver as primeiras linhas e os tipos de dados
print("--- INFO IP DATA ---")
print(df_ip.info())
print("\n--- INFO PTD DATA ---")
print(df_pt.info())

# Visualizar as primeiras 5 linhas de cada um para confirmar a leitura
display(df_ip.head())
display(df_pt.head())
# Out:
# --- INFO IP DATA ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9300 entries, 0 to 9299
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Ano                           9300 non-null   int64
#  1   Mês                           9300 non-null   int64
#  2   Distrito                      9300 non-null   object
#  3   Concelho                      9300 non-null   object
#  4   Freguesia                     9300 non-null   object
#  5   Tipo de Lâmpada               9300 non-null   object
#  6   Luminárias                    9299 non-null   float64
#  7   Lâmpadas por Luminária        9258 non-null   float64
#  8   Lâmpadas                      9258 non-null   float64
#  9   Potência Instalada Total (W)  8483 non-null   float64
#  10  CodDistrito                   9300 non-null   int64
#  11  CodDistritoConcelho           9300 non-null   int64
#  12  coddistritoconcelhofreguesia  9300 non-null   object
# dtypes: float64(4), int64(4), object(5)
# memory usage: 944.7+ KB
# None
#
# --- INFO PTD DATA ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72027 entries, 0 to 72026
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Código de Instalação           72027 non-null  object
#  1   Coordenadas Geográficas        72027 non-null  object
#  2   Potência instalada [kVA]       72027 non-null  int64
#  3   Nível de Utilização [%]        68963 non-null  object
#  4   Tipo Construtivo               72027 non-null  object
#  5   Potência Contratada [kVA]      50847 non-null  float64
#  6   Número de Clientes             72027 non-null  object
#  7   Potência Geração [kW]          1836 non-null   float64
#  8   Número de Clientes Produtores  72027 non-null  object
#  9   CodDistritoConcelho            72027 non-null  int64
#  10  Concelho                       72027 non-null  object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 6.0+ MB
# None
#     Ano  Mês Distrito    Concelho   Freguesia      Tipo de Lâmpada  \
# 0  2026    2   Leiria  Alvaiázere    Almoster                  LED
# 1  2026    2   Leiria  Alvaiázere    Almoster  Outros/Não definido
# 2  2026    2   Leiria  Alvaiázere    Almoster                Sódio
# 3  2026    2   Leiria  Alvaiázere       Pelmá             Mercúrio
# 4  2026    2   Leiria  Alvaiázere  Alvaiázere             Mercúrio
#
#    Luminárias  Lâmpadas por Luminária  Lâmpadas  Potência Instalada Total (W)  \
# 0       716.0                   715.0     715.0                  29010.800171
# 1        23.0                    23.0      23.0                    225.000000
# 2        27.0                    26.0      26.0                   1890.000000
# 3         1.0                     1.0       1.0                     50.000000
# 4         3.0                     3.0       3.0                    150.000000
#
#    CodDistrito  CodDistritoConcelho coddistritoconcelhofreguesia
# 0           10                 1002                       100201
# 1           10                 1002                       100201
# 2           10                 1002                       100201
# 3           10                 1002                       100205
# 4           10                 1002                       100208
#   Código de Instalação              Coordenadas Geográficas  \
# 0         1307D2012500  41.1849010463209, -8.14785254356171
# 1         1307D2012900  41.0869934226954, -8.24673374651495
# 2         1307D2013100  41.1129221154249, -8.21276525945275
# 3         1307D2013800  41.1329530486552, -8.13563404382479
# 4         1307D2015100  41.1228444565974, -8.11290068900831
#
#    Potência instalada [kVA] Nível de Utilização [%]  \
# 0                       400                 60%-79%
# 1                       250                 60%-79%
# 2                       250                 60%-79%
# 3                        50                   +100%
# 4                       250                  0%-19%
#
#                      Tipo Construtivo  Potência Contratada [kVA]  \
# 0                Cabine pré-fabricada                    1052.69
# 1  Cabine baixa integrada em edifício                     775.20
# 2                         Cabine alta                    1104.19
# 3                          Aéreo - AS                     238.07
# 4                          Aéreo - AI                     608.51
#
#   Número de Clientes  Potência Geração [kW] Número de Clientes Produtores  \
# 0                131                    NaN                           <20
# 1                115                    NaN                           <20
# 2                176                    NaN                           <20
# 3                 36                    NaN                           <20
# 4                 94                    NaN                           <20
#
#    CodDistritoConcelho            Concelho
# 0                 1307  Marco de Canaveses
# 1                 1307  Marco de Canaveses
# 2                 1307  Marco de Canaveses
# 3                 1307  Marco de Canaveses
# 4                 1307  Marco de Canaveses

# %% [markdown]
# ### 3. Manipulação de Dados (ETL)

# %% [markdown]
# #### Processamento da Iluminação Pública (IP_data)

# %%
# 1. Criar variável binária Is_Ineficiente
# 1 se for Sódio ou Mercúrio, 0 para outros
df_ip['Is_Ineficiente'] = df_ip['Tipo de Lâmpada'].apply(lambda x: 1 if x in ['Sódio', 'Mercúrio'] else 0)

# 2. Criar variável Potência kW
df_ip['Potencia_kW'] = df_ip['Potência Instalada Total (W)'] / 1000

# 3. Agrupar por Distrito e Concelho 
df_ip_grouped = df_ip.groupby(['CodDistrito', 'Concelho','CodDistritoConcelho']).agg(
    P_IP_Total=('Potencia_kW', 'sum'),        # [cite: 114]
    P_IP_Inef=('Potencia_kW', lambda x: x[df_ip.loc[x.index, 'Is_Ineficiente'] == 1].sum())
).reset_index()

# %% [markdown]
# #### Processamento dos Postos de Transformação (PTD_data)

# %%
# 1. Converter 'Nível de Utilização [%]' para decimal (ex: '60%-79%' -> 0.79)
# Nota: O enunciado sugere usar o limite superior do intervalo
def convert_utilizacao(valor):
    if isinstance(valor, str) and '%' in valor:
        # Extrai o segundo número se houver um intervalo, ou apenas o número
        import re
        nums = re.findall(r'\d+', valor)
        if nums:
            return float(nums[-1]) / 100
    return np.nan

df_pt['Util_Decimal'] = df_pt['Nível de Utilização [%]'].apply(convert_utilizacao)

# 2. Agrupar por Distrito e Concelho
df_pt_grouped = df_pt.groupby(['CodDistritoConcelho']).agg(
    Cap_PTD=('Potência instalada [kVA]', 'sum'), # [cite: 119]
    Util_Media=('Util_Decimal', 'mean'),         # [cite: 120]
    N_PTDs=('Concelho', 'count')                 # [cite: 121]
).reset_index()

# %% [markdown]
# #### Criação do Dataset Consolidado

# %%
# Unir os datasets
df_final = pd.merge(df_ip_grouped, df_pt_grouped, on='CodDistritoConcelho', how='inner')

# Cálculo das métricas solicitadas:
# Ganho LED
df_final['Delta_P_LED'] = df_final['P_IP_Inef'] * 0.65

# Folga Rede (com margem de segurança de 92%)
df_final['P_Folga'] = (df_final['Cap_PTD'] * 0.92) * (1 - df_final['Util_Media'])

# Carga VE (carregadores de 22 kW com fator de simultaneidade de 0.60)
df_final['P_VE'] = df_final['N_PTDs'] * 22 * 0.60

# Saldo Final de Viabilidade (D)
df_final['D'] = df_final['P_Folga'] + df_final['Delta_P_LED'] - df_final['P_VE']

# Rate Ineficiencia
df_final['Rate_Ineficiencia'] = df_final['P_IP_Inef'] / df_final['P_IP_Total']

# Ver dataset final
display(df_final.head())
# Out:
#    CodDistrito            Concelho  CodDistritoConcelho   P_IP_Total  \
# 0            1  Albergaria-a-Velha                  102   451.711801
# 1            1              Anadia                  103   657.071801
# 2            1              Arouca                  104   585.974400
# 3            1              Aveiro                  105  1055.192001
# 4            1    Castelo de Paiva                  106   391.710100
#
#    P_IP_Inef  Cap_PTD  Util_Media  N_PTDs  Delta_P_LED       P_Folga    P_VE  \
# 0     28.020    54540    0.469948     194     18.21300  26596.303834  2560.8
# 1     73.545    55628    0.543009     223     47.80425  23387.762452  2943.6
# 2    115.720    41884    0.527387     236     75.21800  18211.314133  3115.2
# 3    144.420   197485    0.475475     509     93.87300  95298.999935  6718.8
# 4    137.900    25760    0.543228     128     89.63500  10825.122772  1689.6
#
#               D  Rate_Ineficiencia
# 0  24053.716834           0.062031
# 1  20491.966702           0.111928
# 2  15171.332133           0.197483
# 3  88674.072935           0.136866
# 4   9225.157772           0.352046

# %% [markdown]
# Esta secção descreve o processo de pré-processamento e consolidação dos dados dos ficheiros IP_data.xlsx e PT_data.xlsx.
# ##### Processamento de Iluminação Pública (IP):
# >Foi criada a variável binária Is_Ineficiente (1 para lâmpadas de Sódio/Mercúrio) e a potência foi convertida para kW. Os dados foram agregados por concelho para obter a potência total (P_IP_Total) e a potência ineficiente (P_IP_Inef).
# ##### Processamento dos Postos de Transformação (PTD):
# >O 'Nível de Utilização [%]' foi normalizado para valores decimais (ex: 0.79). Agregaram-se os dados por concelho para calcular a capacidade instalada (Cap_PTD), utilização média (Util_Media) e o número de postos (N_PTDs).
# ##### Consolidação e Novas Variáveis:
# > Os datasets foram fundidos via CodDistritoConcelho, permitindo o cálculo das métricas de viabilidade:
# >* Ganho LED ($\Delta P_{LED}$): Potência libertada pela substituição tecnológica ($P_{IP\_Inef} \times 0.65$).
# >* Folga Rede ($P_{Folga}$): Capacidade disponível considerando uma margem de segurança de 92%.Carga VE ($P_{VE}$):
# >* Estimativa de carga para novos carregadores de 22 kW.
# >* Saldo Final (D): Indicador de viabilidade técnica do projeto ($P_{Folga} + \Delta P_{LED} - P_{VE}$).
# >* Rate Ineficiência: Rácio que mede o peso da tecnologia obsoleta no concelho.

# %% [markdown]
# ### 4. Análise e Exploração de Dados

# %% [markdown]
# #### Mix Tecnológico e Concentração de Potência

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Preparar dados para o Mix Tecnológico
total_inef = df_final['P_IP_Inef'].sum()
total_eficiente = df_final['P_IP_Total'].sum() - total_inef

plt.figure(figsize=(8, 6))
plt.pie([total_inef, total_eficiente], labels=['Convencional', 'LED/Eficiente'], 
        autopct='%1.1f%%', colors=['#ff9999','#66b3ff'], startangle=90, explode=(0.05, 0))
plt.title('Mix Tecnológico da Iluminação Pública')
plt.show()

# 2. Análise de Concentração (Municípios com mais potência ineficiente)
top_municipios = df_final.sort_values('P_IP_Inef', ascending=False).head(10)
plt.figure(figsize=(10, 5))
sns.barplot(
    x='P_IP_Inef', 
    y='Concelho', 
    data=top_municipios, 
    hue='Concelho', 
    palette='Reds_r', 
    legend=False
)
plt.title('Top 10 Municípios por Potência Ineficiente (kW)')
plt.xlabel('Potência Ineficiente (kW)')
plt.show()

# %% [markdown]
# Concentração (Ponto 4.3.1): Ao olhares para o gráfico de barras, deves comentar no teu artigo se a potência ineficiente está "concentrada num grupo restrito de municípios". Se as primeiras barras forem muito maiores que as restantes, a resposta é sim.

# %% [markdown]
# #### Distribuição por Distrito (Boxplots)

# %%
# Filtrar apenas os distritos solicitados
distritos_alvo = [1, 11, 13, 15] # Aveiro, Lisboa, Porto, Setúbal
df_boxplot = df_final[df_final['CodDistrito'].isin(distritos_alvo)]

plt.figure(figsize=(10, 6))
sns.boxplot(x='CodDistrito', y='Util_Media', data=df_boxplot)
plt.title('Distribuição do Nível de Utilização dos PTDs por Distrito')
plt.xticks([0, 1, 2, 3], ['Aveiro', 'Lisboa', 'Porto', 'Setúbal'])
plt.ylabel('Utilização Média (Decimal)')
plt.show()

# %% [markdown]
# #### Valores Omissos e Outliers

# %%
# 1. Valores Omissos (NaN)
valores_omissos = df_pt['Nível de Utilização [%]'].isna().sum()

# 2. Valores Indeterminados (<20), no dataset: 0%-19%
mascara_indeterminados = df_pt['Nível de Utilização [%]'].astype(str).str.contains('0%-19%|N/D', case=False, na=False)
valores_indeterminados = mascara_indeterminados.sum()

total_falhas = valores_omissos + valores_indeterminados
total_registos = len(df_pt)
percentagem = (total_falhas / total_registos) * 100

print(f"Valores omissos (NaN): {valores_omissos}")
print(f"Valores indeterminados (<20 ou N/D): {valores_indeterminados}")
print(f"Prevalência total: {total_falhas} registos ({percentagem:.2f}% do total de PTDs).")
# Out:
# Valores omissos (NaN): 3064
# Valores indeterminados (<20 ou N/D): 14338
# Prevalência total: 17402 registos (24.16% do total de PTDs).

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 4))

# Criar o Boxplot usando a coluna decimal que preparámos
sns.boxplot(x=df_pt['Util_Decimal'], color='lightgreen', fliersize=6, linewidth=1.5)

# Adicionar títulos e rótulos
plt.title('Identificação de Outliers nos Níveis de Ocupação da Rede (PTDs)')
plt.xlabel('Nível de Utilização (Decimal)')

# Adicionar uma linha vermelha para destacar o limite crítico de 100% (1.0)
plt.axvline(x=1.0, color='red', linestyle='--', label='Capacidade Crítica (100%)')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Através da análise do diagrama de extremos e quartis (Boxplot) representativo do nível de ocupação da rede, observa-se que 50% dos Postos de Transformação operam confortavelmente entre os 38% e 58% da sua capacidade. No entanto, o gráfico evidencia a presença de outliers críticos no extremo superior da distribuição. A concentração de valores atípicos junto e acima da linha de capacidade máxima (100%) revela a existência de infraestruturas em sobrecarga. Estes postos constituem estrangulamentos na rede, onde a instalação de postos de carregamento para mobilidade elétrica é tecnicamente inviável sem prévia intervenção de expansão de capacidade.

# %% [markdown]
# #### Estatística Descritiva (Municípios Específicos)

# %%
# Lista de concelhos pretendida
concelhos_foco = ['Coimbra', 'Évora', 'Braga', 'Faro']

# 1. Filtramos o dataset original (df_pt) que contém os dados de CADA posto individual
# Certifica-te que usas a coluna 'Util_Decimal' que criámos no ETL
df_pt_foco = df_pt[df_pt['Concelho'].isin(concelhos_foco)]

# 2. Calculamos as estatísticas sobre a distribuição de todos os postos de cada concelho
resumo_estatistico = df_pt_foco.groupby('Concelho')['Util_Decimal'].agg([
    'mean',                     # Média
    'std',                      # Desvio Padrão
    lambda x: x.quantile(0.25), # Q1 (1º Quartil)
    'median',                   # Mediana (Q2)
    lambda x: x.quantile(0.75), # Q3 (3º Quartil)
    'skew',                     # Assimetria
    lambda x: x.kurtosis()      # Curtose
]).reset_index()

# 3. Renomear as colunas para ficar profissional
resumo_estatistico.columns = ['Concelho', 'Média', 'Desvio Padrão', 'Q1', 'Mediana', 'Q3', 'Assimetria', 'Curtose']

# 4. Apresentar com as 4 casas decimais exigidas no enunciado
display(resumo_estatistico.round(4))
# Out:
#   Concelho   Média  Desvio Padrão    Q1  Mediana    Q3  Assimetria  Curtose
# 0    Braga  0.5423         0.2401  0.39     0.59  0.79      0.4280  -0.7116
# 1  Coimbra  0.5406         0.2322  0.39     0.59  0.79      0.2258  -0.7060
# 2     Faro  0.5549         0.2126  0.39     0.59  0.59      0.3009  -0.4757
# 3    Évora  0.4546         0.2425  0.19     0.39  0.59      0.6680  -0.4254

# %% [markdown]
# No teu artigo podes adicionar uma breve interpretação destes resultados:
#
# >* Média e Mediana: Faro é o concelho com a rede mais carregada em média (55,49%), enquanto Évora é o mais "desafogado" (45,46%).
#
# >* Desvio Padrão: Os valores andam todos à volta de 0.21 a 0.24, o que mostra que a variação de carga entre os vários transformadores dentro da mesma cidade é semelhante em todos os concelhos analisados.
#
# >* Assimetria (Skewness): Sendo positiva em todos, significa que a cauda da distribuição se estende para a direita (existem mais postos com cargas baixas/médias do que postos em sobrecarga extrema).
#
# >* Curtose: Os valores negativos (perto de -0.7 e -0.4) indicam distribuições mais "achatadas" (platicúrticas) do que a curva normal, significando que as cargas estão bem espalhadas pelos vários níveis de utilização, em vez de estarem todas concentradas num único valor central.

# %% [markdown]
# ### 5. Inferência Estatística

# %% [markdown]
# O objetivo final é responder à pergunta: "Com base nestes 50 concelhos, posso garantir matematicamente que a rede elétrica nacional tem uma ocupação média abaixo de 60% (0.60), provando que temos folga para instalar carregadores de carros elétricos?"

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Selecionar uma amostra aleatória de 50 concelhos
# Usamos random_state=42 para que os 50 concelhos escolhidos sejam sempre os mesmos cada vez que correres o código
amostra_50 = df_final['Util_Media'].sample(n=50, random_state=42).dropna()

print("==================================================")
print("1. TESTE DE NORMALIDADE (Shapiro-Wilk)")
print("==================================================")
# H0: Os dados seguem uma distribuição Normal
# H1: Os dados NÃO seguem uma distribuição Normal
stat_sw, p_sw = stats.shapiro(amostra_50)

print(f"p-value: {p_sw:.4f}")

# Nível de significância padrão é 5% (0.05)
if p_sw > 0.05:
    print("-> Conclusão: A amostra segue uma distribuição Normal.")
    is_normal = True
else:
    print("-> Conclusão: A amostra NÃO segue uma distribuição Normal.")
    is_normal = False


print("\n==================================================")
print("2. TESTE DE HIPÓTESES (Média < 0.60)")
print("==================================================")
patamar = 0.60

if is_normal:
    # Se for normal, usamos o Teste T de 1 amostra (unicaudal à esquerda: alternative='less')
    print("Teste selecionado: T-Test para 1 amostra (Paramétrico)")
    stat_test, p_test = stats.ttest_1samp(amostra_50, popmean=patamar, alternative='less')
else:
    # Se não for normal, usamos o teste de Wilcoxon (unicaudal à esquerda)
    print("Teste selecionado: Wilcoxon Signed-Rank Test (Não Paramétrico)")
    # No Wilcoxon subtraímos o patamar à amostra para testar se a mediana das diferenças é < 0
    stat_test, p_test = stats.wilcoxon(amostra_50 - patamar, alternative='less')

print(f"p-value do teste: {p_test:.4f}")

if p_test < 0.05:
    print("-> Conclusão Final: Rejeitamos H0.")
    print("Há evidências estatísticas significativas de que o nível médio de ocupação da rede é INFERIOR a 60%. Há folga na rede!")
else:
    print("-> Conclusão Final: Não rejeitamos H0.")
    print("NÃO há evidências estatísticas de que o nível médio de ocupação da rede seja inferior a 60%. Não há folga na rede!")

# Opcional: Um pequeno gráfico para veres a tua amostra de 50 concelhos
plt.figure(figsize=(6, 4))
sns.histplot(amostra_50, kde=True, color='skyblue')
plt.axvline(x=patamar, color='red', linestyle='--', label='Patamar de Referência (60%)')
plt.axvline(x=amostra_50.mean(), color='green', linestyle='-', label=f'Média da Amostra ({amostra_50.mean():.2f})')
plt.title('Distribuição da Ocupação na Amostra de 50 Concelhos')
plt.xlabel('Nível de Utilização Médio')
plt.legend()
plt.show()
# Out:
# ==================================================
# 1. TESTE DE NORMALIDADE (Shapiro-Wilk)
# ==================================================
# p-value: 0.0717
# -> Conclusão: A amostra segue uma distribuição Normal.
#
# ==================================================
# 2. TESTE DE HIPÓTESES (Média < 0.60)
# ==================================================
# Teste selecionado: T-Test para 1 amostra (Paramétrico)
# p-value do teste: 0.0000
# -> Conclusão Final: Rejeitamos H0.
# Há evidências estatísticas significativas de que o nível médio de ocupação da rede é INFERIOR a 60%. Há folga na rede!

# %% [markdown]
# Ou seja: será que nos concelhos onde a e-REDES instalou muitos transformadores potentes (Cap_PTD), também existe um gasto muito elevado com a iluminação pública (P_IP_Total)?
# > A Correlação de Pearson vai dar-nos um número ($r$) entre -1 e 1. Se estiver perto de 1, significa que quando um sobe, o outro sobe quase na mesma proporção. O p-value vai dizer-nos se podemos confiar nesse resultado.

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Limpar eventuais valores nulos nas colunas de interesse
df_corr = df_final.dropna(subset=['Cap_PTD', 'P_IP_Total'])

# 2. Extrair as duas variáveis
capacidade = df_corr['Cap_PTD']
iluminacao = df_corr['P_IP_Total']

print("==================================================")
print("TESTE DE CORRELAÇÃO DE PEARSON (Totalidade dos Concelhos)")
print("==================================================")

# 3. Calcular o Coeficiente de Pearson e o p-value
r_pearson, p_value = stats.pearsonr(capacidade, iluminacao)

print(f"Coeficiente de Correlação (r): {r_pearson:.4f}")
print(f"p-value: {p_value:.4e}") # Notação científica, pois o valor deve ser muito próximo de zero

# 4. Conclusão Estatística (nível de significância = 0.05)
if p_value < 0.05:
    print("\n-> Conclusão: Rejeitamos H0.")
    print("Existe uma relação linear ESTATISTICAMENTE SIGNIFICATIVA entre a Capacidade de Transformação e a Iluminação Pública.")
else:
    print("\n-> Conclusão: Não rejeitamos H0.")
    print("NÃO existe uma relação linear estatisticamente significativa.")

# 5. Representação Gráfica
plt.figure(figsize=(8, 6))
# regplot cria o gráfico de pontos com a linha de regressão linear a vermelho
sns.regplot(x=capacidade, y=iluminacao, scatter_kws={'alpha':0.6, 'color':'#3498db'}, line_kws={'color':'red'})

plt.title('Relação entre Capacidade de Transformação e Iluminação Pública')
plt.xlabel('Capacidade Total de Transformação Instalada (kW)')
plt.ylabel('Carga Total de Iluminação Pública (kW)')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# ==================================================
# TESTE DE CORRELAÇÃO DE PEARSON (Totalidade dos Concelhos)
# ==================================================
# Coeficiente de Correlação (r): 0.9111
# p-value: 3.1324e-108
#
# -> Conclusão: Rejeitamos H0.
# Existe uma relação linear ESTATISTICAMENTE SIGNIFICATIVA entre a Capacidade de Transformação e a Iluminação Pública.

# %% [markdown]
# Para avaliar a relação linear entre a capacidade total de transformação instalada e a carga total de iluminação pública nos concelhos, recorreu-se ao coeficiente de correlação de Pearson. O teste revelou um coeficiente de $r = 0.9111$, evidenciando uma correlação linear positiva muito forte. Adicionalmente, o teste de significância resultou num p-value praticamente nulo ($p < 0.001$), rejeitando-se a hipótese nula com elevado grau de confiança estatística. Como ilustrado no gráfico de dispersão, confirma-se que o dimensionamento da infraestrutura de transformação (Cap_PTD) nos municípios portugueses acompanha de forma altamente proporcional e linear as necessidades de carga da iluminação pública.

# %% [markdown]
# 1. Os pontos muito abaixo da linha vermelha (Por exemplo, aqueles dois pontos perto do 0.6 e 0.7 no eixo do X, mas muito em baixo no eixo do Y):
#
# > O que significam matematicamente: Têm um valor de X (Capacidade) muito alto, mas um valor de Y (Iluminação) muito baixo para o esperado.
#
# > O que significam no mundo real: São concelhos que têm uma infraestrutura elétrica gigante, mas gastam muito pouca energia a iluminar as ruas.
#
# > Porquê? Podem ser concelhos fortemente industriais (como Sines ou Palmela, onde os transformadores gigantes servem fábricas e não candeeiros) ou podem ser concelhos que já substituíram 100% da sua iluminação por LED, reduzindo drasticamente a carga (o eixo do Y) sem precisarem de deitar os transformadores fora (o eixo do X).
#
# 2. Os pontos muito acima da linha vermelha
# (Há ali um ponto perto do 0.5 no eixo do X que dispara para cima):
#
# > O que significam matematicamente: Têm muito mais Y (Iluminação) do que seria de esperar para o X (Capacidade) que possuem.
#
# > O que significam no mundo real: São concelhos com redes elétricas modestas, mas com um gasto brutal em iluminação pública.
#
# > Porquê? Podem ser concelhos com redes de iluminação totalmente obsoletas e ineficientes (lâmpadas antigas de mercúrio), ou concelhos com muita densidade turística/histórica que exige iluminação noturna excessiva.

# %% [markdown]
# ### 6. Correlação e Regressão - Modelo Preditivo

# %% [markdown]
# > O que é para fazer: O professor quer que tu olhes apenas para os distritos de Aveiro, Braga, Lisboa e Porto. Nesses 4 distritos, tens de cruzar a Capacidade dos Transformadores (Cap_PTD) com a Potência da Iluminação Pública (P_IP_Total) para ver se andam de mãos dadas (Correlação de Pearson).
#
# > Objetivo: Descobrir se os distritos que têm mais capacidade instalada também são os que gastam mais em iluminação.
#
# > Como fazer: Filtrar o dataset por esses 4 distritos e gerar uma pequena matriz de correlação 2x2.

# %% [markdown]
# Modelo de Regressão Linear Múltipla (Para Portugal Continental)O que é para fazer:
#  Agora vais olhar para Portugal Continental inteiro. O objetivo é criar uma fórmula preditiva (uma máquina de adivinhar).
#  Tu queres dar 3 "pistas" ao computador ($X_1, X_2, X_3$) e ver se ele consegue adivinhar a ocupação do transformador ($Y$).
#  As tuas "Pistas" (Variáveis Independentes):
# >* Quanta potência de luz existe no concelho $X_1$
# >* Quanta capacidade os transformadores têm $X_2$
# >* Qual é a taxa de lâmpadas antigas (ineficiência) $X_3$
#
#  O teu "Alvo" (Variável Dependente):$Y$:
# >*  A utilização média do transformador.Objetivo: Obter a equação matemática: $Y = \beta_0 + \beta_1 X_1 + \beta_2 X_2 + \beta_3 X_3$

# %%
import pandas as pd
import statsmodels.api as sm

# =======================================================
# PARTE 1: Tabela de Correlação (Aveiro, Braga, Lisboa, Porto)
# =======================================================
print("--- 1. Tabela de Correlação (4 Distritos) ---")

# Aveiro(1), Braga(3), Lisboa(11), Porto(13)
distritos_foco = [1, 3, 11, 13] 
df_corr = df_final[df_final['CodDistrito'].isin(distritos_foco)]

tabela_corr = df_corr[['Cap_PTD', 'P_IP_Total']].corr(method='pearson')
display(tabela_corr)
# Out:
# --- 1. Tabela de Correlação (4 Distritos) ---
#              Cap_PTD  P_IP_Total
# Cap_PTD     1.000000    0.912912
# P_IP_Total  0.912912    1.000000

# %% [markdown]
# > A matriz de correlação calculada para os distritos de Aveiro, Braga, Lisboa e Porto revelou um coeficiente de Pearson de r = 0.9129 entre a Capacidade Nominal de Transformação (Cap_PTD) e a Potência Instalada de Iluminação Pública (P_IP_Total). Este resultado evidencia uma correlação positiva muito forte nestes distritos, demonstrando que o dimensionamento da infraestrutura elétrica acompanha de forma quase linear as elevadas exigências de carga da iluminação pública nos grandes centros urbanos.

# %%
# =======================================================
# PARTE 2: Modelo de Regressão Linear Múltipla (Portugal Continental)
# =======================================================
print("\n--- 2. Modelo de Regressão Linear Múltipla ---")

# Filtrar para Portugal Continental (Códigos de Distrito de 1 a 18)
# O dropna garante que limpamos concelhos sem dados nestas 4 colunas
colunas_modelo = ['P_IP_Total', 'Cap_PTD', 'Rate_Ineficiencia', 'Util_Media']
df_cont = df_final[(df_final['CodDistrito'] >= 1) & (df_final['CodDistrito'] <= 18)].dropna(subset=colunas_modelo)

# Definir as variáveis X (Pistas) e Y (Alvo)
X = df_cont[['P_IP_Total', 'Cap_PTD', 'Rate_Ineficiencia']]
Y = df_cont['Util_Media']

# Adicionar a constante (Intercepto Beta 0) - Obrigatório para a fórmula matemática
X = sm.add_constant(X)

# Criar e treinar o modelo (OLS - Ordinary Least Squares)
modelo_rlm = sm.OLS(Y, X).fit()

# Mostrar os resultados completos do modelo
print(modelo_rlm.summary())
# Out:
# --- 2. Modelo de Regressão Linear Múltipla ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Util_Media   R-squared:                       0.074
# Model:                            OLS   Adj. R-squared:                  0.064
# Method:                 Least Squares   F-statistic:                     7.300
# Date:                Thu, 19 Mar 2026   Prob (F-statistic):           0.000100
# Time:                        13:32:02   Log-Likelihood:                 367.10
# No. Observations:                 278   AIC:                            -726.2
# Df Residuals:                     274   BIC:                            -711.7
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 0.4989      0.006     86.585      0.000       0.488       0.510
# P_IP_Total         4.594e-05    1.3e-05      3.546      0.000    2.04e-05    7.14e-05
# Cap_PTD             -2.7e-07   7.22e-08     -3.738      0.000   -4.12e-07   -1.28e-07
# Rate_Ineficiencia     0.0127      0.023      0.558      0.577      -0.032       0.058
# ==============================================================================
# Omnibus:                        5.595   Durbin-Watson:                   1.433
# Prob(Omnibus):                  0.061   Jarque-Bera (JB):                4.920
# Skew:                          -0.251   Prob(JB):                       0.0854
# Kurtosis:                       2.585   Cond. No.                     9.72e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.72e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# > Através da regressão linear múltipla (OLS) para Portugal Continental, obteve-se um modelo preditivo para a Utilização Média da rede com a seguinte equação: $Y = 0.4989 + 4.594\times 10^{-5} X_1 - 2.7\times 10^{-7} X_2 + 0.0127 X_3$. O modelo apresenta um baixo coeficiente de determinação ($R^2 = 0.074$), indicando que as variáveis selecionadas apenas explicam 7,4% da variância observada, visto omitirem os consumos domésticos e industriais. A análise de significância revela que a Potência de Iluminação e a Capacidade do PTD são variáveis estatisticamente significativas (p-value < 0.001), enquanto a Ineficiência não tem impacto estatístico no modelo (p-value = 0.577). Por fim, o modelo alerta para a presença de forte multicolinearidade, justificável pela correlação superior a 90% encontrada anteriormente entre as infraestruturas de transformação e iluminação.

# %%
import scipy.stats as stats
import statsmodels.stats.api as sms

# Extrair os resíduos (erros) do modelo que criaste antes (modelo_rlm)
residuos = modelo_rlm.resid

# 1. Normalidade (Teste de Shapiro-Wilk)
stat_sw, p_sw = stats.shapiro(residuos)
print(f"Normalidade (Shapiro-Wilk): p-value = {p_sw:.4f}")

# 2. Independência (Estatística de Durbin-Watson)
dw_stat = sm.stats.stattools.durbin_watson(residuos)
print(f"Independência (Durbin-Watson): Estatística = {dw_stat:.4f}")

# 3. Homocedasticidade (Teste de Breusch-Pagan)
stat_bp, p_bp, _, _ = sms.het_breuschpagan(residuos, modelo_rlm.model.exog)
print(f"Homocedasticidade (Breusch-Pagan): p-value = {p_bp:.4f}")
# Out:
# Normalidade (Shapiro-Wilk): p-value = 0.0301
# Independência (Durbin-Watson): Estatística = 1.4330
# Homocedasticidade (Breusch-Pagan): p-value = 0.1710

# %% [markdown]
# > Para validar o modelo de regressão linear múltipla, procedeu-se à verificação dos pressupostos sobre os resíduos. A análise revelou o incumprimento parcial das condições ideais. Através do teste de Shapiro-Wilk, rejeitou-se a normalidade da distribuição dos resíduos (p-value = 0.0301 < 0.05). Adicionalmente, a estatística de Durbin-Watson fixou-se em 1.433, valor marginalmente inferior ao limiar aceitável de 1.5, indicando a presença de autocorrelação positiva e violando o pressuposto da independência. Em contrapartida, o teste de Breusch-Pagan não permitiu rejeitar a hipótese nula (p-value = 0.1710 > 0.05), confirmando a homocedasticidade da variância dos resíduos. Estas limitações nos resíduos são coerentes com o baixo coeficiente de determinação do modelo, refletindo a omissão de variáveis explicativas fundamentais para a carga da rede.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

print("==================================================")
print("3. CÁLCULO DO VIF (Variance Inflation Factor)")
print("==================================================\n")

# Criar um DataFrame em branco para apresentar os resultados de forma bonita
vif_data = pd.DataFrame()

# A variável X já tem as tuas 3 variáveis + a constante (que adicionámos antes)
vif_data["Variável"] = X.columns

# Calcular o VIF para cada uma das colunas no X
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Mostrar a tabela final, arredondada a 2 casas decimais
display(vif_data.round(2))
# Out:
# ==================================================
# 3. CÁLCULO DO VIF (Variance Inflation Factor)
# ==================================================
#             Variável   VIF
# 0              const  2.18
# 1         P_IP_Total  8.45
# 2            Cap_PTD  7.26
# 3  Rate_Ineficiencia  1.52

# %% [markdown]
# A regra de ouro na estatística é simples:
#
# > VIF = 1: Não há multicolinearidade nenhuma.
#
# > VIF entre 1 e 5: Multicolinearidade moderada (aceitável).
#
# > VIF > 5 (ou > 10 em alguns autores): Multicolinearidade severa! As variáveis estão a dizer a mesma coisa e a destruir a precisão do modelo.

# %% [markdown]
# Interpretação dos Teus Resultados:
# > P_IP_Total (VIF = 8.45) e Cap_PTD (VIF = 7.26): Como ambos os valores são superiores a 5, o teste reprova estas duas variáveis por multicolinearidade severa. O Python está a dizer-te: "A Potência de Iluminação e a Capacidade do Transformador dão-me 8 vezes a mesma informação. Estão a confundir os meus cálculos!".
#
# > Rate_Ineficiencia (VIF = 1.52): Como é muito inferior a 5 (está perto de 1), significa que esta variável é independente das outras. Não sofre de multicolinearidade. (O problema dela, como vimos no p-value do modelo, é que simplesmente não serve para prever a carga da rede).
#
# > const (VIF = 2.18): Na estatística, ignoramos sempre o VIF da constante, por isso não precisas de falar nisto.

# %% [markdown]
# Para verificar a presença de multicolinearidade entre as variáveis explicativas, procedeu-se ao cálculo do Variance Inflation Factor (VIF). A análise revelou que as variáveis Potência Instalada de Iluminação Pública ($X_1$) e Capacidade Nominal de Transformação ($X_2$) apresentam valores de VIF de 8.45 e 7.26, respetivamente. Sendo ambos os valores superiores ao limiar crítico de 5, confirma-se matematicamente a existência de multicolinearidade severa no modelo. Este resultado corrobora a forte correlação de Pearson ($r = 0.91$) previamente detetada, provando que a inclusão simultânea destas infraestruturas inflaciona a variância dos coeficientes e compromete a precisão preditiva do modelo. Em contraste, a Taxa de Ineficiência ($X_3$) obteve um VIF de 1.52, demonstrando ausência de problemas de colinearidade.

# %% [markdown]
# #### Ponto 4.5.3

# %% [markdown]
# > A avaliação da qualidade do modelo de regressão linear múltipla evidencia uma capacidade preditiva muito limitada, traduzida por um coeficiente de determinação ajustado ($R^2_{adj}$) de 0.064. Este valor indica que os preditores selecionados apenas conseguem explicar 6,4% da variabilidade observada no nível médio de ocupação da rede. Esta limitação decorre da exclusão de variáveis de maior peso no consumo energético municipal, como o setor industrial e o consumo doméstico.
# > Relativamente à significância estatística dos preditores (avaliada a um nível de significância $\alpha = 0.05$), constata-se que a Potência Instalada de Iluminação Pública ($X_1$) e a Capacidade Nominal de Transformação ($X_2$) são variáveis estatisticamente significativas (p-value < 0.001). Pelo contrário, a Taxa de Ineficiência ($X_3$) apresentou um p-value de 0.577, demonstrando que a proporção de lâmpadas com tecnologia obsoleta não possui significância estatística para explicar a ocupação global da infraestrutura de transformação do concelho.

# %%
import pandas as pd
import statsmodels.api as sm

# 1. Definir os códigos dos concelhos pedidos no enunciado
codigos_alvo = [101, 102, 103, 104, 105, 106, 107, 108, 109]
codigo_conc = 'CodDistritoConcelho' 

# 2. Filtrar os dados reais apenas para estes concelhos
df_teste = df_final[df_final[codigo_conc].isin(codigos_alvo)].copy()

# 3. Preparar as "pistas" (Variáveis X) e adicionar a Constante (obrigatório para o modelo prever corretamente)
X_teste = df_teste[['P_IP_Total', 'Cap_PTD', 'Rate_Ineficiencia']]
X_teste = sm.add_constant(X_teste, has_constant='add')

# 4. Usar o modelo para fazer a estimativa matemática (Y Previsto)
y_previsto = modelo_rlm.predict(X_teste)

# 5. Criar uma tabela de comparação lado a lado
tabela_comparacao = pd.DataFrame({
    'Código': df_teste[codigo_conc],
    'Concelho': df_teste['Concelho'], # Se a tua coluna de nome se chamar de outra forma, ajusta aqui
    'Y Real': df_teste['Util_Media'],
    'Y Previsto': y_previsto
})

# 6. Calcular a diferença (Erro) entre a realidade e o modelo
tabela_comparacao['Erro'] = tabela_comparacao['Y Real'] - tabela_comparacao['Y Previsto']

# Mostrar os resultados arredondados a 4 casas decimais
display(tabela_comparacao.round(4))
# Out:
#     Código              Concelho  Y Real  Y Previsto    Erro
# 0      102    Albergaria-a-Velha  0.4699      0.5057 -0.0358
# 1      103                Anadia  0.5430      0.5155  0.0275
# 2      104                Arouca  0.5274      0.5170  0.0104
# 3      105                Aveiro  0.4755      0.4958 -0.0203
# 4      106      Castelo de Paiva  0.5432      0.5144  0.0288
# 5      107               Espinho  0.4434      0.5014 -0.0580
# 6      108             Estarreja  0.5076      0.5074  0.0002
# 12     109  Santa Maria da Feira  0.5829      0.5372  0.0457
# 17     101                Águeda  0.4776      0.5156 -0.0380

# %% [markdown]
# Para testar a aplicabilidade prática do modelo de regressão linear múltipla desenvolvido, procedeu-se à estimativa do Nível de Utilização Médio ($Y$) para uma amostra de nove municípios do distrito de Aveiro. A comparação direta entre os valores previstos e as ocupações reais ($Y$ Real) confirma a limitada capacidade preditiva do modelo. >
# Observa-se que as estimativas do modelo assumem um comportamento conservador, concentrando-se numa faixa muito estreita (entre 49% e 53%), sendo incapazes de captar a verdadeira variação da rede. Como resultado, o modelo subestima substancialmente a ocupação em concelhos de maior dimensão ou densidade (como Santa Maria da Feira, com um erro de ~4.6%) e superestima em concelhos com consumos atípicos (como Espinho, com erro de ~5.8%). Estes desvios práticos corroboram o baixo coeficiente de determinação obtido ($R^2 = 7.4\%$), provando definitivamente que as variáveis de iluminação e capacidade de transformação são insuficientes para estimar a saturação de um Posto de Transformação num cenário real de planeamento da rede.

# %% [markdown]
# #### Ponto 4.5.6
#
# > Para quantificar a redução esperada no nível de ocupação da rede ($Y$) face a uma diminuição de 20% no rácio de ineficiência ($X_3$), recorre-se ao coeficiente $\beta_3$ obtido no modelo de regressão. Matematicamente, o impacto isolado desta medida seria calculado pelo produto entre o coeficiente e a variação da variável: $\Delta Y = 0.0127 \times (-0.20) = -0.00254$. Isto traduzir-se-ia numa redução marginal de apenas 0,25% na carga média dos postos de transformação.No entanto, é fundamental interpretar este resultado à luz da inferência estatística. Como verificado anteriormente, o preditor da taxa de ineficiência apresentou um p-value de 0.577 ($p > 0.05$). Deste modo, conclui-se que o coeficiente $\beta_3$ não é estatisticamente diferente de zero. Na prática, isto significa que a implementação de tecnologia LED na iluminação pública, embora benéfica a outros níveis, não tem um impacto estatisticamente significativo ou mensurável na desocupação global da rede elétrica, não sendo uma medida eficaz para criar a 'folga' necessária para a instalação de carregadores de veículos elétricos.

# %%
print("================================================================")
print("CONCELHOS MAIS VIÁVEIS (Baseado nos Intervalos de Confiança)")
print("================================================================\n")

# 1. Obter as previsões completas com os intervalos de confiança a 95% (alpha=0.05)
# O get_prediction gera os intervalos de previsão (obs_ci) que têm em conta a incerteza do modelo
previsoes_completas = modelo_rlm.get_prediction(X).summary_frame(alpha=0.05)

# 2. Criar uma tabela
df_viabilidade = pd.DataFrame({
    'Concelho': df_cont['Concelho'],
    'Y_Real': Y,
    'Y_Previsto': previsoes_completas['mean'],
    'Limite_Inf_95%': previsoes_completas['obs_ci_lower'],
    'Limite_Sup_95%': previsoes_completas['obs_ci_upper']
})

# 3. Ordenar pelos concelhos com o Limite Superior MAIS BAIXO
top_viaveis = df_viabilidade.sort_values(by='Limite_Sup_95%', ascending=True).head(5)

display(top_viaveis.round(4))
# Out:
# ================================================================
# CONCELHOS MAIS VIÁVEIS (Baseado nos Intervalos de Confiança)
# ================================================================
#               Concelho  Y_Real  Y_Previsto  Limite_Inf_95%  Limite_Sup_95%
# 189              Porto  0.4219      0.3940          0.2481          0.5399
# 194  Vila Nova de Gaia  0.4179      0.4002          0.2592          0.5412
# 153             Lisboa  0.4005      0.4382          0.2792          0.5972
# 100              Évora  0.4546      0.4885          0.3598          0.6173
# 23                Beja  0.4467      0.4928          0.3642          0.6213

# %% [markdown]
# Para avaliar a viabilidade estatística de instalação de carregadores de veículos elétricos de 22 kW, procedeu-se à análise dos intervalos de confiança das previsões do modelo (nível de confiança de 95%). Num contexto de engenharia de redes, a tomada de decisão para a alocação de nova carga não deve basear-se apenas na média prevista, mas sim no limite superior do intervalo de confiança (Limite_Sup_95%), que representa o cenário mais conservador de saturação da rede.
# > A análise identificou que municípios de grande densidade urbana como o Porto e Vila Nova de Gaia apresentam os limites superiores de previsão mais baixos do país (53,99% e 54,12%, respetivamente). Segue-se Lisboa, com um limite máximo esperado de 59,72%. Nestes concelhos, existe evidência estatística de que a rede possui uma folga de potência superior a 40%, sendo capaz de absorver os picos de carga gerados por infraestruturas de carregamento rápido sem comprometer a estabilidade dos Postos de Transformação. Contudo, dado o baixo poder explicativo geral do modelo ($R^2_{adj} = 6.4\%$), recomenda-se que estas previsões macroscópicas sejam validadas com medições locais antes da instalação física dos equipamentos.
